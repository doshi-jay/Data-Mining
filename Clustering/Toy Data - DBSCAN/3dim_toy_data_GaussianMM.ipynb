# %%
from scipy.stats import multivariate_normal
from random import randint
import numpy as np

# %%
x, y = [], []
file = open("3gaussian.txt", 'r')
k = 3
for line in file:
    x.append(float(line.split()[0]))
    y.append(float(line.split()[1]))

# %%
u = [[2,2], [6,3], [4,6]]
cov_mat = [[[1,0],[0,2]], [[1,0.9], [0.9,1]], [[1, 0.9], [0.9, 1]]]
weights = {0: 0.323, 1: 0.328, 2: 0.349}
pi_0 = {}
pi_1 = {}
pi_2 = {}

# %%
def probablity(data_point, u, cov_mat):
    var = multivariate_normal(mean=u, cov=cov_mat)
    prob = var.pdf([data_point[0], data_point[1]])
    return prob

# %%
def expectation():
    for i in range(0, len(x)):
        data_point = (x[i], y[i])
        probs = []
        for j in range(0, k):
            prob = probablity(data_point, u[j], cov_mat[j])
            if j == 0:
                pi_0[data_point] = prob * weights[0]
            elif j == 1:
                pi_1[data_point] = prob * weights[1]
            else:
                pi_2[data_point] = prob * weights[2]
            probs.append((prob, j))
        denom = 0
        for prob in probs:
            label = prob[1]
            denom += prob[0] * weights[label]

        pi_0[data_point] /= denom
        pi_1[data_point] /= denom
        pi_2[data_point] /= denom

# %%
def maximization():
    weights[0] = sum(list(pi_0.values())) / len(x)
    weights[1] = sum(list(pi_1.values())) / len(x)
    weights[2] = sum(list(pi_2.values())) / len(x)
    sum_u0_x = 0
    sum_u0_y = 0
    sum_u1_x = 0
    sum_u1_y = 0
    sum_u2_x = 0
    sum_u2_y = 0
    for i in range(0, len(x)):
        data_point = (x[i], y[i])
        p0 = pi_0[data_point]
        p1 = pi_1[data_point]
        p2 = pi_2[data_point]
        sum_u0_x += (p0 * x[i])
        sum_u0_y += (p0 * y[i])
        sum_u1_x += (p1 * x[i])
        sum_u1_y += (p1 * y[i])
        sum_u2_x += (p2 * x[i])
        sum_u2_y += (p2 * y[i])
    sum_u0_x /= sum(list(pi_0.values()))
    sum_u0_y /= sum(list(pi_0.values()))
    sum_u1_x /= sum(list(pi_1.values()))
    sum_u1_y /= sum(list(pi_1.values()))
    sum_u2_x /= sum(list(pi_2.values()))
    sum_u2_y /= sum(list(pi_2.values()))
    u[0][0] = sum_u0_x
    u[0][1] = sum_u0_y
    u[1][0] = sum_u1_x
    u[1][1] = sum_u1_y
    u[2][0] = sum_u2_x
    u[2][1] = sum_u2_y
    update_cov_mat()

# %%
def update_cov_mat():
    final_cov_mat0 = [[0,0], [0,0]]
    final_cov_mat1 = [[0,0], [0,0]]
    final_cov_mat2 = [[0,0], [0,0]]
    for i in range(len(x)):
        data_point = (x[i], y[i])
        prob0 = pi_0[data_point]
        prob1 = pi_1[data_point]
        prob2 = pi_2[data_point]
        
        factor01 = [data_point[0] - u[0][0], data_point[1] - u[0][1]]
        factor01 = np.array(factor01).reshape(1,-1)
        factor02 = np.dot(factor01.reshape(-1,1), factor01)
        factor03 = prob0 * factor02
        
        for m in range(2):
            for n in range(2):
                final_cov_mat0[m][n] += factor03[m][n]
        
        factor11 = [data_point[0] - u[1][0], data_point[1] - u[1][1]]
        factor11 = np.array(factor11).reshape(1,-1)
        factor12 = np.dot(factor11.reshape(-1,1), factor11)
        factor13 = prob1 * factor12
        
        for m in range(2):
            for n in range(2):
                final_cov_mat1[m][n] += factor13[m][n]
                
        factor21 = [data_point[0] - u[2][0], data_point[1] - u[2][1]]
        factor21 = np.array(factor21).reshape(1,-1)
        factor22 = np.dot(factor21.reshape(-1,1), factor21)
        factor23 = prob2 * factor22
        
        for m in range(2):
            for n in range(2):
                final_cov_mat2[m][n] += factor23[m][n]
                
    for m in range(2):
        for n in range(2):
            final_cov_mat0[m][n] = final_cov_mat0[m][n] / sum(list(pi_0.values()))
    
    for m in range(2):
        for n in range(2):
            final_cov_mat1[m][n] = final_cov_mat1[m][n] / sum(list(pi_1.values()))
    
    for m in range(2):
        for n in range(2):
            final_cov_mat2[m][n] = final_cov_mat2[m][n] / sum(list(pi_2.values()))
    
    cov_mat[0] = final_cov_mat0
    cov_mat[1] = final_cov_mat1
    cov_mat[2] = final_cov_mat2

# %%
def repeat_untill_convergence():
    i = 0
    while(i <= 76):
        print("Iteration: " + str(i))
        expectation()
        print("Expectation done")
        maximization()
        print("Maximization done")
        print("Mean 1: ", end = " ")
        print(u[0])
        print("Mean 2: ", end = " ")
        print(u[1])
        print("Mean 3: ", end = " ")
        print(u[2])
        print("Covariance 1: ", end = " ")
        print(cov_mat[0])
        print("Covariance 2: ", end = " ")
        print(cov_mat[1])
        print("Covariance 3: ", end = " ")
        print(cov_mat[2])
        print("Weights: ", end = " ")
        print(weights)
        print("=============================================")
        i += 1

# %%
repeat_untill_convergence()
# Out:
# Iteration: 0
# Expectation done
# Maximization done
# Mean 1:  [3.2173589954742741, 3.573353315400063]
# Mean 2:  [6.916258079078812, 3.9308918720488526]
# Mean 3:  [4.9076929630955277, 6.8763679118867609]
# Covariance 1:  [[1.5157658896686761, 0.69294070283565223], [0.69294070283565223, 5.6225548964876833]]
# Covariance 2:  [[1.246548567972138, 0.82193639005949826], [0.82193639005949826, 1.3083416716337857]]
# Covariance 3:  [[1.0748014947950191, 0.57963505179417196], [0.57963505179417196, 1.095612464344738]]
# Weights:  {0: 0.19737083254298637, 1: 0.31466285235763547, 2: 0.48796631509937743}
# =============================================
# Iteration: 1
# Expectation done
# Maximization done
# Mean 1:  [3.1968331859618258, 3.5136618322255178]
# Mean 2:  [6.9712402744356563, 4.0018247222554146]
# Mean 3:  [4.9758093570545814, 6.9465976287983091]
# Covariance 1:  [[1.3072651630082799, 0.65469137898380714], [0.65469137898380714, 5.1640511695743472]]
# Covariance 2:  [[1.1082639050692749, 0.60584403938582287], [0.60584403938582287, 1.1285158069734587]]
# Covariance 3:  [[1.006371757069656, 0.36214254680491803], [0.36214254680491803, 1.0180040786226576]]
# Weights:  {0: 0.21609127796772501, 1: 0.30805528823295719, 2: 0.47585343379932099}
# =============================================
# Iteration: 2
# Expectation done
# Maximization done
# Mean 1:  [3.1707622249029908, 3.4436063588352419]
# Mean 2:  [6.9995163432637719, 4.0196661558209934]
# Mean 3:  [5.0162607553731515, 6.9954326393236395]
# Covariance 1:  [[1.1974691624171716, 0.49616025725481722], [0.49616025725481722, 4.6723669251856199]]
# Covariance 2:  [[1.0365593201897891, 0.53495105276501875], [0.53495105276501875, 1.0578862140157006]]
# Covariance 3:  [[0.96825393025942996, 0.25647950178298079], [0.25647950178298079, 0.96028469091235302]]
# Weights:  {0: 0.22354192327295094, 1: 0.30373125298390169, 2: 0.47272682374314628}
# =============================================
# Iteration: 3
# Expectation done
# Maximization done
# Mean 1:  [3.1540242480380947, 3.3936542974632573]
# Mean 2:  [7.0153159896750337, 4.0236830581146101]
# Mean 3:  [5.0375189258623969, 7.0204244713138468]
# Covariance 1:  [[1.143640303687973, 0.37427274982117315], [0.37427274982117315, 4.3449932959353577]]
# Covariance 2:  [[1.0027758990849571, 0.51051019555801436], [0.51051019555801436, 1.0283253847278797]]
# Covariance 3:  [[0.94741017800646277, 0.20608006329220754], [0.20608006329220754, 0.93400049313387556]]
# Weights:  {0: 0.22642690485057243, 1: 0.30086307862374934, 2: 0.47271001652567912}
# =============================================
# Iteration: 4
# Expectation done
# Maximization done
# Mean 1:  [3.1418420717901223, 3.355486169033878]
# Mean 2:  [7.0238994394756711, 4.0243700165372855]
# Mean 3:  [5.0465621331498438, 7.0305272872299716]
# Covariance 1:  [[1.1169307220292082, 0.29713557213875258], [0.29713557213875258, 4.1462127252080991]]
# Covariance 2:  [[0.98648535513894509, 0.50092823747296045], [0.50092823747296045, 1.013927116532445]]
# Covariance 3:  [[0.93798793613599507, 0.18266135907420292], [0.18266135907420292, 0.92631942570873826]]
# Weights:  {0: 0.22681828051969796, 1: 0.29916714933687683, 2: 0.47401457014342457}
# =============================================
# Iteration: 5
# Expectation done
# Maximization done
# Mean 1:  [3.1318448154260787, 3.3236240450511554]
# Mean 2:  [7.0283817006774001, 4.0241069551727833]
# Mean 3:  [5.0490064806267769, 7.033094637958615]
# Covariance 1:  [[1.1022858041784875, 0.24843516332412077], [0.24843516332412077, 4.0210708688217931]]
# Covariance 2:  [[0.97864841863952778, 0.49693459467097106], [0.49693459467097106, 1.0063522549972765]]
# Covariance 3:  [[0.9354745959621602, 0.17228368503404914], [0.17228368503404914, 0.9265748041390498]]
# Weights:  {0: 0.22595233712627233, 1: 0.29821119384879774, 2: 0.47583646902492782}
# =============================================
# Iteration: 6
# Expectation done
# Maximization done
# Mean 1:  [3.123060737546377, 3.2956512463501784]
# Mean 2:  [7.0305317069981328, 4.0235168256604883]
# Mean 3:  [5.0482521092499999, 7.0323699281041545]
# Covariance 1:  [[1.0929488830594298, 0.2153894119333421], [0.2153894119333421, 3.9342639193734525]]
# Covariance 2:  [[0.97512666039839757, 0.49534379296209613], [0.49534379296209613, 1.0021660242946593]]
# Covariance 3:  [[0.93654525852920067, 0.16814727667224186], [0.16814727667224186, 0.92966335777293518]]
# Weights:  {0: 0.22453684362871651, 1: 0.29769536778552286, 2: 0.4777677885857608}
# =============================================
# Iteration: 7
# Expectation done
# Maximization done
# Mean 1:  [3.1150878933943154, 3.2705088514178438]
# Mean 2:  [7.0313659281264975, 4.0228335981154926]
# Mean 3:  [5.0460852396938112, 7.0303935119591605]
# Covariance 1:  [[1.0860084114393951, 0.19079580776709246], [0.19079580776709246, 3.8674888394430535]]
# Covariance 2:  [[0.97386802852727927, 0.49484607658158059], [0.49484607658158059, 0.99974654719740985]]
# Covariance 3:  [[0.93922069343306958, 0.16696251854548572], [0.16696251854548572, 0.93353703260767151]]
# Weights:  {0: 0.22293671401241655, 1: 0.29743710099496068, 2: 0.47962618499262344}
# =============================================
# Iteration: 8
# Expectation done
# Maximization done
# Mean 1:  [3.1077554268909409, 3.2476941162858051]
# Mean 2:  [7.0314680501612541, 4.0221580673347415]
# Mean 3:  [5.0433809125255555, 7.028041586260783]
# Covariance 1:  [[1.0802349812609822, 0.1710130044801314], [0.1710130044801314, 3.812116831075008]]
# Covariance 2:  [[0.97380397115089157, 0.49485056055278842], [0.49485056055278842, 0.99828571888678896]]
# Covariance 3:  [[0.94247685591276997, 0.16715584504597281], [0.16715584504597281, 0.93743491925211608]]
# Weights:  {0: 0.22132614707323997, 1: 0.29732840999187349, 2: 0.48134544293488651}
# =============================================
# Iteration: 9
# Expectation done
# Maximization done
# Mean 1:  [3.1009898913235445, 3.2269376808618828]
# Mean 2:  [7.0311697332910006, 4.0215274833327239]
# Mean 3:  [5.040553469716583, 7.0256634382679781]
# Covariance 1:  [[1.0751222040265387, 0.15426268915138025], [0.15426268915138025, 3.7641877411845694]]
# Covariance 2:  [[0.97436677962706741, 0.49508400879572995], [0.49508400879572995, 0.99736681565645802]]
# Covariance 3:  [[0.94582920103568358, 0.16798094143538686], [0.16798094143538686, 0.94110090625170217]]
# Weights:  {0: 0.21978377621491904, 1: 0.29730607438154999, 2: 0.48291014940352905}
# =============================================
# Iteration: 10
# Expectation done
# Maximization done
# Mean 1:  [3.0947572154131082, 3.2080666155998196]
# Mean 2:  [7.0306588880771868, 4.020950058213038]
# Mean 3:  [5.0377945182707355, 7.0233892105309916]
# Covariance 1:  [[1.0704686419791216, 0.13966762538674238], [0.13966762538674238, 3.7218273812677185]]
# Covariance 2:  [[0.97525068478781651, 0.49541956100569234], [0.49541956100569234, 0.99676777898553826]]
# Covariance 3:  [[0.94906446559895141, 0.1690826140894883], [0.1690826140894883, 0.94446846566659592]]
# Weights:  {0: 0.21834260688513554, 1: 0.29733306985643543, 2: 0.48432432325842767}
# =============================================
# Iteration: 11
# Expectation done
# Maximization done
# Mean 1:  [3.0890364703334487, 3.1909456795102522]
# Mean 2:  [7.0300429278480179, 4.0204231734941906]
# Mean 3:  [5.035189449336344, 7.0212626052292961]
# Covariance 1:  [[1.0661967580528988, 0.12677054271518837], [0.12677054271518837, 3.684060892365546]]
# Covariance 2:  [[0.97628775833158155, 0.49579755047924323], [0.49579755047924323, 0.99636600026726307]]
# Covariance 3:  [[0.95209708229152967, 0.17028860323243833], [0.17028860323243833, 0.94753711529524354]]
# Weights:  {0: 0.21701418994175384, 1: 0.29738752167358529, 2: 0.48559828838465702}
# =============================================
# Iteration: 12
# Expectation done
# Maximization done
# Mean 1:  [3.0838085815977383, 3.1754533665632656]
# Mean 2:  [7.0293843001735707, 4.0199416204580762]
# Mean 3:  [5.0327728984657449, 7.0192946166642427]
# Covariance 1:  [[1.0622756462783618, 0.11530642038364927], [0.11530642038364927, 3.6502965535716805]]
# Covariance 2:  [[0.97738324757096406, 0.49618881032106571], [0.49618881032106571, 0.99609104935031523]]
# Covariance 3:  [[0.95489901094925722, 0.17151257519517427], [0.17151257519517427, 0.95032592661788062]]
# Weights:  {0: 0.21579996394261811, 1: 0.29745633001174615, 2: 0.48674370604563483}
# =============================================
# Iteration: 13
# Expectation done
# Maximization done
# Mean 1:  [3.0790521756733331, 3.1614731451579074]
# Mean 2:  [7.0287199747664904, 4.0195005928565752]
# Mean 3:  [5.0305549680934165, 7.0174842679315486]
# Covariance 1:  [[1.0586891500451348, 0.10509818698319663], [0.10509818698319663, 3.6201082951476278]]
# Covariance 2:  [[0.97848208297651762, 0.49657805185426429], [0.49657805185426429, 0.99590069981704421]]
# Covariance 3:  [[0.95746723779401266, 0.1727094629411205], [0.1727094629411205, 0.95285737295217132]]
# Weights:  {0: 0.21469654927224438, 1: 0.29753154245053348, 2: 0.48777190827722317}
# =============================================
# Iteration: 14
# Expectation done
# Maximization done
# Mean 1:  [3.0747426952366541, 3.1488910266917673]
# Mean 2:  [7.0280720787462005, 4.0190963618421858]
# Mean 3:  [5.028533711339005, 7.0158262320605234]
# Covariance 1:  [[1.055423599791236, 0.096010198328354474], [0.096010198328354474, 3.5931464069791477]]
# Covariance 2:  [[0.97955151261160689, 0.49695652932272238], [0.49695652932272238, 0.99576850576041698]]
# Covariance 3:  [[0.95980928832334655, 0.17385488664805998], [0.17385488664805998, 0.95515259508347883]]
# Weights:  {0: 0.2136982555779893, 1: 0.29760828771164993, 2: 0.48869345671035991}
# =============================================
# Iteration: 15
# Expectation done
# Maximization done
# Mean 1:  [3.0708528762202714, 3.1375955799502768]
# Mean 2:  [7.0274537744505405, 4.0187261244060624]
# Mean 3:  [5.0267011898782723, 7.0143134899788668]
# Covariance 1:  [[1.0524638070382746, 0.087928041536424945], [0.087928041536424945, 3.5691019120024086]]
# Covariance 2:  [[0.98057195891490634, 0.49731885942914639], [0.49731885942914639, 0.99567720337216226]]
# Covariance 3:  [[0.96193696653074967, 0.17493552123659425], [0.17493552123659425, 0.95723059951031153]]
# Weights:  {0: 0.21279831233500207, 1: 0.29768358377531956, 2: 0.48951810388967643}
# =============================================
# Iteration: 16
# Expectation done
# Maximization done
# Mean 1:  [3.0673536758187074, 3.1274787467272338]
# Mean 2:  [7.026872601018546, 4.0183876708933619]
# Mean 3:  [5.0250465100537456, 7.0129382286518851]
# Covariance 1:  [[1.0497923540855467, 0.080750034084794226], [0.080750034084794226, 3.5476928615877954]]
# Covariance 2:  [[0.9815320420950191, 0.49766163175412881], [0.49766163175412881, 0.99561510159597255]]
# Covariance 3:  [[0.96386370747932293, 0.17594442792274809], [0.17594442792274809, 0.95910857181318954]]
# Weights:  {0: 0.21198950822776075, 1: 0.29775563571621522, 2: 0.49025485605602714}
# =============================================
# Iteration: 17
# Expectation done
# Maximization done
# Mean 1:  [3.0642152403795269, 3.1184367878109667]
# Mean 2:  [7.0263324526853532, 4.0180791008718142]
# Mean 3:  [5.023557415388848, 7.0116921751210946]
# Covariance 1:  [[1.0473900572864905, 0.074383758768756608], [0.074383758768756608, 3.5286592798548302]]
# Covariance 2:  [[0.98242572966299324, 0.49798276234453093], [0.49798276234453093, 0.99557403894164331]]
# Covariance 3:  [[0.96560345609489162, 0.17687865263686831], [0.17687865263686831, 0.96080233955561589]]
# Weights:  {0: 0.21126454801731698, 1: 0.29782341086231756, 2: 0.49091204112036502}
# =============================================
# Iteration: 18
# Expectation done
# Maximization done
# Mean 1:  [3.0614077466988232, 3.1103711026843088]
# Mean 2:  [7.025834806724494, 4.0177986387151332]
# Mean 3:  [5.0222211690571132, 7.0105667784707286]
# Covariance 1:  [[1.0452367292498348, 0.068744667299220782], [0.068744667299220782, 3.511761309181574]]
# Covariance 2:  [[0.98325059719213703, 0.49828114620557057], [0.49828114620557057, 0.99554818180888838]]
# Covariance 3:  [[0.96717016469468975, 0.17773788106366686], [0.17773788106366686, 0.96232671691053018]]
# Weights:  {0: 0.21061626604593495, 1: 0.29788637406130858, 2: 0.49149735989275678}
# =============================================
# Iteration: 19
# Expectation done
# Maximization done
# Mean 1:  [3.0589020658738124, 3.1031888404065242]
# Mean 2:  [7.0253795224596098, 4.0175445367019442]
# Mean 3:  [5.0210250706412882, 7.0095533614768541]
# Covariance 1:  [[1.0433119052860387, 0.063755465065330683], [0.063755465065330683, 3.496778380297938]]
# Covariance 2:  [[0.98400669591634693, 0.49855643009283351], [0.49855643009283351, 0.99553328846352152]]
# Covariance 3:  [[0.96857753289943449, 0.17852360716786675], [0.17852360716786675, 0.96369570230518031]]
# Weights:  {0: 0.21003776021435575, 1: 0.29794431777032127, 2: 0.49201792201532374}
# =============================================
# Iteration: 20
# Expectation done
# Maximization done
# Mean 1:  [3.0566702506133141, 3.0968032918178388]
# Mean 2:  [7.0249653827960215, 4.0173150383814766]
# Mean 3:  [5.0199567720581779, 7.0086432653665387]
# Covariance 1:  [[1.0415954273269834, 0.059345741251117211], [0.059345741251117211, 3.4835085804855819]]
# Covariance 2:  [[0.98469577323237734, 0.49880883853160124], [0.49880883853160124, 0.99552623936972839]]
# Covariance 3:  [[0.96983884351432259, 0.17923856981908876], [0.17923856981908876, 0.96492256644356689]]
# Weights:  {0: 0.20952247704085347, 1: 0.29799725000073252, 2: 0.49248027295841401}
# =============================================
# Iteration: 21
# Expectation done
# Maximization done
# Mean 1:  [3.0546858676651709, 3.0911340828889191]
# Mean 2:  [7.0245904726025294, 4.0171083774356662]
# Mean 3:  [5.0190044743969668, 7.0078279836858473]
# Covariance 1:  [[1.0400678702891559, 0.055451638102565155], [0.055451638102565155, 3.4717679412848099]]
# Covariance 2:  [[0.98532071425024392, 0.49903902999158672], [0.49903902999158672, 0.99552472548419269]]
# Covariance 3:  [[0.97096684253451304, 0.17988634453270178], [0.17988634453270178, 0.96601987465764805]]
# Weights:  {0: 0.20906426373473155, 1: 0.29804531870808476, 2: 0.4928904175571841}
# =============================================
# Iteration: 22
# Expectation done
# Maximization done
# Mean 1:  [3.0529242031608868, 3.0861072000404453]
# Mean 2:  [7.0242524481812518, 4.0169227941649686]
# Mean 3:  [5.0181570485142739, 7.007099277695235]
# Covariance 1:  [[1.0387108291615406, 0.052015493250703947], [0.052015493250703947, 3.4613895826230299]]
# Covariance 2:  [[0.98588513223756225, 0.49924797594505221], [0.49924797594505221, 0.99552703387191332]]
# Covariance 3:  [[0.97197364737814218, 0.18047103605002121], [0.18047103605002121, 0.96699947751825377]]
# Weights:  {0: 0.20865739660925997, 1: 0.29808875988611627, 2: 0.49325384350462392}
# =============================================
# Iteration: 23
# Expectation done
# Maximization done
# Mean 1:  [3.0513623682370845, 3.0816548807813438]
# Mean 2:  [7.0239487307559587, 4.0167565582600329]
# Mean 3:  [5.01740410365292, 7.0064492686068425]
# Covariance 1:  [[1.0375070940614868, 0.048985445235417896], [0.048985445235417896, 3.4522227292921572]]
# Covariance 2:  [[0.98639306549343231, 0.49943686030984641], [0.49943686030984641, 0.99553189566524936]]
# Covariance 3:  [[0.97287067927344117, 0.18099704349522755], [0.18099704349522755, 0.96787249180675905]]
# Weights:  {0: 0.2082965920196807, 1: 0.2981278615457989, 2: 0.49357554643452151}
# =============================================
# Iteration: 24
# Expectation done
# Maximization done
# Mean 1:  [3.0499793291762058, 3.0777154015278811]
# Mean 2:  [7.0236766451726096, 4.0166079914032]
# Mean 3:  [5.0167360191553394, 7.005870505501929]
# Covariance 1:  [[1.0364407399107771, 0.046315012266697507], [0.046315012266697507, 3.4441316394645987]]
# Covariance 2:  [[0.9868487534801037, 0.49960699767601241], [0.49960699767601241, 0.99553837551314395]]
# Covariance 3:  [[0.97366861841142471, 0.18146888146573473], [0.18146888146573473, 0.96864928451948651]]
# Weights:  {0: 0.2079770043533751, 1: 0.29816293862054311, 2: 0.49386005702608182}
# =============================================
# Iteration: 25
# Expectation done
# Maximization done
# Mean 1:  [3.0487558823724821, 3.0742327910999383]
# Mean 2:  [7.0234335182277006, 4.0164754864860033]
# Mean 3:  [5.0161439494978497, 7.0053560103228696]
# Covariance 1:  [[1.0354971535482469, 0.043962658988413748], [0.043962658988413748, 3.4369944870724694]]
# Covariance 2:  [[0.98725647339516287, 0.49975976852647525], [0.49975976852647525, 0.99554578964269025]]
# Covariance 3:  [[0.97437738023102916, 0.18189104577249554], [0.18189104577249554, 0.9693394660838196]]
# Weights:  {0: 0.20769421458078355, 1: 0.29819431554656578, 2: 0.49411146987264981}
# =============================================
# Iteration: 26
# Expectation done
# Maximization done
# Mean 1:  [3.0476745905294957, 3.0711564942537697]
# Mean 2:  [7.0232167468928512, 4.0163575222129522]
# Mean 3:  [5.0156198100806204, 7.0048993027891129]
# Covariance 1:  [[1.0346630166150315, 0.04189136489454974], [0.04189136489454974, 3.4307022342599511]]
# Covariance 2:  [[0.9876204233197744, 0.49989656936571136], [0.49989656936571136, 0.99555364428025628]]
# Covariance 3:  [[0.97500611040564467, 0.18226791523651895], [0.18226791523651895, 0.96995189488070255]]
# Weights:  {0: 0.20744421215000672, 1: 0.29822231431873353, 2: 0.49433347353125917}
# =============================================
# Iteration: 27
# Expectation done
# Maximization done
# Mean 1:  [3.0467196929962985, 3.068441005334694]
# Mean 2:  [7.0230238440024682, 4.016252672978351]
# Mean 3:  [5.0151562494154565, 7.0044944086880374]
# Covariance 1:  [[1.0339262584171014, 0.040068205096659558], [0.040068205096659558, 3.4251575224325279]]
# Covariance 2:  [[0.98794464130124759, 0.50001877553216734], [0.50001877553216734, 0.99556158894186408]]
# Covariance 3:  [[0.97556319552288262, 0.18260368252398734], [0.18260368252398734, 0.97049469280269562]]
# Weights:  {0: 0.20722337243634692, 1: 0.29824724649120471, 2: 0.49452938107244843}
# =============================================
# Iteration: 28
# Expectation done
# Maximization done
# Mean 1:  [3.0458770001690314, 3.0660454880789567]
# Mean 2:  [7.0228524671075059, 4.0161596144740646]
# Mean 3:  [5.0147466120801383, 7.0041358550409818]
# Covariance 1:  [[1.0332759894946775, 0.038463950997819102], [0.038463950997819102, 3.4202736029229599]]
# Covariance 2:  [[0.98823295201599648, 0.50012771450934945], [0.50012771450934945, 0.99556938080562241]]
# Covariance 3:  [[0.97605628624214569, 0.18290230811879662], [0.18290230811879662, 0.97097527035250453]]
# Weights:  {0: 0.2070284314858408, 1: 0.2982694080325583, 2: 0.49470216048160137}
# =============================================
# Iteration: 29
# Expectation done
# Maximization done
# Mean 1:  [3.0451337794311217, 3.0639333939498798]
# Mean 2:  [7.0227004348519024, 4.016077125723073]
# Mean 3:  [5.0143848958323574, 7.0038186553796793]
# Covariance 1:  [[1.0327024238391069, 0.037052695695237947], [0.037052695695237947, 3.4159733217828361]]
# Covariance 2:  [[0.98848893439251606, 0.50022464771525432], [0.50022464771525432, 0.99557685746761204]]
# Covariance 3:  [[0.97649232981467848, 0.18316749244649366], [0.18316749244649366, 0.97140035927896362]]
# Weights:  {0: 0.20685645939713121, 1: 0.29828907624472079, 2: 0.49485446435814484}
# =============================================
# Iteration: 30
# Expectation done
# Maximization done
# Mean 1:  [3.0444786381316487, 3.0620720882521604]
# Mean 2:  [7.022565734215978, 4.0160040882868042]
# Mean 3:  [5.0140657055013076, 7.0035382879485031]
# Covariance 1:  [[1.0321967955196714, 0.03581150676940157], [0.03581150676940157, 3.4121881678913852]]
# Covariance 2:  [[0.98871590494172235, 0.50031075898380828], [0.50031075898380828, 0.99558391610485764]]
# Covariance 3:  [[0.97687760914971367, 0.18340266196885788], [0.18340266196885788, 0.97177605066405726]]
# Weights:  {0: 0.20670483335790191, 1: 0.29830650816491955, 2: 0.49498865847717616}
# =============================================
# Iteration: 31
# Expectation done
# Maximization done
# Mean 1:  [3.0439014075444399, 3.0604324906410763]
# Mean 2:  [7.0224465211969473, 4.0159394833477728]
# Mean 3:  [5.0137842056442601, 7.0032906691804424]
# Covariance 1:  [[1.0317512738138579, 0.034720107500126149], [0.034720107500126149, 3.4088573894093552]]
# Covariance 2:  [[0.98891691264454107, 0.50038714821081953], [0.50038714821081953, 0.99559049756553464]]
# Covariance 3:  [[0.97721778600986942, 0.18361096578935379], [0.18361096578935379, 0.972107836525961]]
# Weights:  {0: 0.20657121108294496, 1: 0.29832194002085555, 2: 0.49510684889620243}
# =============================================
# Iteration: 32
# Expectation done
# Maximization done
# Mean 1:  [3.0433930305410053, 3.0589887345089304]
# Mean 2:  [7.0223411168915986, 4.0158823872788956]
# Mean 3:  [5.0135360734433423, 7.0030721243373524]
# Covariance 1:  [[1.0313588796722575, 0.033760586396012295], [0.033760586396012295, 3.4059271804455031]]
# Covariance 2:  [[0.98909474214140503, 0.50045482889308401], [0.50045482889308401, 0.99559657426106873]]
# Covariance 3:  [[0.97751794634873734, 0.18379527994995989], [0.18379527994995989, 0.9724006532659849]]
# Weights:  {0: 0.20645350518381311, 1: 0.29833558741986682, 2: 0.49521090739632173}
# =============================================
# Iteration: 33
# Expectation done
# Maximization done
# Mean 1:  [3.0429454547853525, 3.0577178480366114]
# Mean 2:  [7.0222480004777736, 4.015831966207192]
# Mean 3:  [5.013317452905917, 7.0028793567899861]
# Covariance 1:  [[1.0310134054075584, 0.032917134137661265], [0.032917134137661265, 3.4033499374855025]]
# Covariance 2:  [[0.98925192269520834, 0.5005147285252548], [0.5005147285252548, 0.99560214099465294]]
# Covariance 3:  [[0.97778264621823618, 0.18395821715895858], [0.18395821715895858, 0.97265892558937661]]
# Weights:  {0: 0.20634985882776713, 1: 0.29834764603518221, 2: 0.49530249513705021}
# =============================================
# Iteration: 34
# Expectation done
# Maximization done
# Mean 1:  [3.0425515325618835, 3.056599458388499]
# Mean 2:  [7.0221658002203089, 4.0157874699779921]
# Mean 3:  [5.0131249111037972, 7.0027094170572743]
# Covariance 1:  [[1.0307093388018349, 0.032175806528918681], [0.032175806528918681, 3.4010835834914124]]
# Covariance 2:  [[0.98939074098513224, 0.50056769102737786], [0.50056769102737786, 0.99560720805603886]]
# Covariance 3:  [[0.97801595704763666, 0.18410214016752602], [0.18410214016752602, 0.97288660982746034]]
# Weights:  {0: 0.20625862290969557, 1: 0.29835829261402452, 2: 0.4953830844762796}
# =============================================
# Iteration: 35
# Expectation done
# Maximization done
# Mean 1:  [3.0422049278319276, 3.055615519538903]
# Mean 2:  [7.0220932833390783, 4.0157482258334856]
# Mean 3:  [5.0129553969286835, 7.0025596724233363]
# Covariance 1:  [[1.0304417923199507, 0.031524311752177958], [0.031524311752177958, 3.3990909564728518]]
# Covariance 2:  [[0.98951325625881081, 0.50061448055380631], [0.50061448055380631, 0.99561179606169836]]
# Covariance 3:  [[0.97822150941796993, 0.18422917741438483], [0.18422917741438483, 0.97308723585892809]]
# Weights:  {0: 0.20617833485845855, 1: 0.29836768617908016, 2: 0.49545397896246329}
# =============================================
# Iteration: 36
# Expectation done
# Maximization done
# Mean 1:  [3.0419000307383115, 3.0547500634944513]
# Mean 2:  [7.0220293453541167, 4.0157136320423232]
# Mean 3:  [5.0128062026431879, 7.0024277777099266]
# Covariance 1:  [[1.0302064377537021, 0.030951820074445455], [0.030951820074445455, 3.3973392586348079]]
# Covariance 2:  [[0.98962131674417186, 0.50065578618283479], [0.50065578618283479, 0.99561593213509569]]
# Covariance 3:  [[0.97840253472363636, 0.18434123988903672], [0.18434123988903672, 0.97326394706118902]]
# Weights:  {0: 0.20610769912265445, 1: 0.2983759693299663, 2: 0.49551633154737612}
# =============================================
# Iteration: 37
# Expectation done
# Maximization done
# Mean 1:  [3.0416318795123454, 3.0539889741623547]
# Mean 2:  [7.0219729993475024, 4.0156831516513511]
# Mean 3:  [5.0126749283561098, 7.0023116475892051]
# Covariance 1:  [[1.0299994463656497, 0.030448794106657736], [0.030448794106657736, 3.395799561820168]]
# Covariance 2:  [[0.98971657651574774, 0.50069222710739103], [0.50069222710739103, 0.99561964711150086]]
# Covariance 3:  [[0.97856190432819445, 0.18444003843253043], [0.18444003843253043, 0.97341953791603208]]
# Weights:  {0: 0.20604556932527954, 1: 0.29838326957807099, 2: 0.49557116109665111}
# =============================================
# Iteration: 38
# Expectation done
# Maximization done
# Mean 1:  [3.0413960895534, 3.0533197827685385]
# Mean 2:  [7.0219233654525111, 4.0156563064804871]
# Mean 3:  [5.0125594494416754, 7.0022094306719973]
# Covariance 1:  [[1.0298174344263595, 0.030006837745914863], [0.030006837745914863, 3.3944463648072123]]
# Covariance 2:  [[0.98980051223991161, 0.50072435804503213], [0.50072435804503213, 0.99562297352279572]]
# Covariance 3:  [[0.97870216599141335, 0.18452710090937863], [0.18452710090937863, 0.97355648904910408]]
# Weights:  {0: 0.20599093203754493, 1: 0.29838970066810044, 2: 0.49561936729435402}
# =============================================
# Iteration: 39
# Expectation done
# Maximization done
# Mean 1:  [3.0411887893320944, 3.0527314835119022]
# Mean 2:  [7.0218796607759195, 4.0156326714377739]
# Mean 3:  [5.0124578868406422, 7.0021194854952071]
# Covariance 1:  [[1.0296574139226635, 0.029618562003807105], [0.029618562003807105, 3.3932571980298625]]
# Covariance 2:  [[0.98987443939925979, 0.50075267466230811], [0.50075267466230811, 0.99562594417195271]]
# Covariance 3:  [[0.97882557747305565, 0.18460378885272047], [0.18460378885272047, 0.97367699960327381]]
# Weights:  {0: 0.20594289209580838, 1: 0.29839536385478793, 2: 0.49566174404940283}
# =============================================
# Iteration: 40
# Expectation done
# Maximization done
# Mean 1:  [3.0410065626931995, 3.0522143680201554]
# Mean 2:  [7.0218411898879971, 4.0156118692050304]
# Mean 3:  [5.0123685801290359, 7.0020403584451163]
# Covariance 1:  [[1.0295167481423406, 0.029277466027185381], [0.029277466027185381, 3.3922122714084706]]
# Covariance 2:  [[0.98993952773192551, 0.50077761886952288], [0.50077761886952288, 0.99562859115101743]]
# Covariance 3:  [[0.97893413731619849, 0.18467131331582684], [0.18467131331582684, 0.97378301693739255]]
# Weights:  {0: 0.2059006593689198, 1: 0.29840034911427032, 2: 0.49569899151680963}
# =============================================
# Iteration: 41
# Expectation done
# Maximization done
# Mean 1:  [3.0408463970964807, 3.0517598771258974]
# Mean 2:  [7.0218073359551108, 4.0155935653160819]
# Mean 3:  [5.0122900632026841, 7.001970763596578]
# Covariance 1:  [[1.0293931117997019, 0.0289778317354056], [0.0289778317354056, 3.3912941611791658]]
# Covariance 2:  [[0.98999681572190112, 0.5007995838878605], [0.5007995838878605, 0.99563094518943107]]
# Covariance 3:  [[0.97902961288077417, 0.18473074976274012], [0.18473074976274012, 0.97387626370912161]]
# Weights:  {0: 0.20586353687403139, 1: 0.29840473627793701, 2: 0.49573172684803146}
# =============================================
# Iteration: 42
# Expectation done
# Maximization done
# Mean 1:  [3.0407056373181143, 3.0513604684852909]
# Mean 2:  [7.0217775525517414, 4.0155774636360526]
# Mean 3:  [5.0122210424050193, 7.0019095644016636]
# Covariance 1:  [[1.029284455348193, 0.028714630624613578], [0.028714630624613578, 3.3904875318535308]]
# Covariance 2:  [[0.990047224052095, 0.50081891902672848], [0.50081891902672848, 0.99563303524635227]]
# Covariance 3:  [[0.97911356574662933, 0.18478305190569166], [0.18478305190569166, 0.97395826244654959]]
# Weights:  {0: 0.20583091013516058, 1: 0.29840859608248149, 2: 0.49576049378235937}
# =============================================
# Iteration: 43
# Expectation done
# Maximization done
# Mean 1:  [3.040581944138439, 3.0510094986036451]
# Mean 2:  [7.0217513561579414, 4.0155633022358321]
# Mean 3:  [5.0121603769157135, 7.0018557571369406]
# Covariance 1:  [[1.0291889731236679, 0.028483441415316505], [0.028483441415316505, 3.3897788897143513]]
# Covariance 2:  [[0.99009156798607711, 0.50083593413531036], [0.50083593413531036, 0.99563488828089863]]
# Covariance 3:  [[0.97918737463561645, 0.18482906445222744], [0.18482906445222744, 0.97403035774525337]]
# Weights:  {0: 0.20580223767878503, 1: 0.29841199113412836, 2: 0.49578577118708883}
# =============================================
# Iteration: 44
# Expectation done
# Maximization done
# Mean 1:  [3.0404732575573874, 3.050701117898126]
# Mean 2:  [7.0217283193281563, 4.0155508496473606]
# Mean 3:  [5.0121070612137313, 7.0018084559977369]
# Covariance 1:  [[1.029105074970291, 0.028280377343106549], [0.028280377343106549, 3.3891563645366243]]
# Covariance 2:  [[0.9901305686833608, 0.50085090371198226], [0.50085090371198226, 0.99563652915035072]]
# Covariance 3:  [[0.97925225602034693, 0.18486953476438023], [0.18486953476438023, 0.97409373624557849]]
# Weights:  {0: 0.20577704256361498, 1: 0.29841497678802126, 2: 0.49580798064836118}
# =============================================
# Iteration: 45
# Expectation done
# Maximization done
# Mean 1:  [3.0403777640999077, 3.0504301775088476]
# Mean 2:  [7.0217080645040104, 4.0155399014806266]
# Mean 3:  [5.0120602094326072, 7.0017668797224335]
# Covariance 1:  [[1.0290313610158812, 0.028102022009718203], [0.028102022009718203, 3.3886095165052299]]
# Covariance 2:  [[0.99016486347994392, 0.5008640706691968], [0.5008640706691968, 0.99563798059829023]]
# Covariance 3:  [[0.97930928259610517, 0.18490512346014615], [0.18490512346014615, 0.9741494445549943]]
# Weights:  {0: 0.20575490484633652, 1: 0.29841760194573275, 2: 0.49582749320793257}
# =============================================
# Iteration: 46
# Expectation done
# Maximization done
# Mean 1:  [3.0402938678026263, 3.0501921466609896]
# Mean 2:  [7.0216902584354868, 4.0155302773791206]
# Mean 3:  [5.0120190414325094, 7.0017303396230322]
# Covariance 1:  [[1.0289665992837516, 0.027945372821621472], [0.027945372821621472, 3.3881291655781052]]
# Covariance 2:  [[0.99019501518356867, 0.50087564976130827], [0.50087564976130827, 0.9956392633047112]]
# Covariance 3:  [[0.97935939979314002, 0.18493641400578373], [0.18493641400578373, 0.97419840528233026]]
# Weights:  {0: 0.20573545489084205, 1: 0.29841990977515181, 2: 0.49584463533400741}
# =============================================
# Iteration: 47
# Expectation done
# Maximization done
# Mean 1:  [3.0402201645018434, 3.0499830394730929]
# Mean 2:  [7.0216746071682454, 4.0155218182889314]
# Mean 3:  [5.0119828704212228, 7.0016982289002296]
# Covariance 1:  [[1.0289097058495154, 0.027807791145343885], [0.027807791145343885, 3.3877072408059181]]
# Covariance 2:  [[0.99022152044368994, 0.5008858306893037], [0.5008858306893037, 0.99564039597681075]]
# Covariance 3:  [[0.97940344050344952, 0.18496392135898401], [0.18496392135898401, 0.97424143134870178]]
# Weights:  {0: 0.20571836743505578, 1: 0.29842193835777137, 2: 0.49585969420717163}
# =============================================
# Iteration: 48
# Expectation done
# Maximization done
# Mean 1:  [3.0401554190736868, 3.0497993502015537]
# Mean 2:  [7.021660851553821, 4.0155143840158223]
# Mean 3:  [5.0119510919700465, 7.0016700131263798]
# Covariance 1:  [[1.0288597272749429, 0.027686958401970899], [0.027686958401970899, 3.3873366473668698]]
# Covariance 2:  [[0.99024481726244606, 0.50089478090071338], [0.50089478090071338, 0.99564139546497854]]
# Covariance 3:  [[0.97944213818917447, 0.18498809972979713], [0.18498809972979713, 0.97427923873410438]]
# Weights:  {0: 0.20570335633596959, 1: 0.29842372126882599, 2: 0.49587292239520603}
# =============================================
# Iteration: 49
# Expectation done
# Maximization done
# Mean 1:  [3.0400985453080001, 3.0496379960024109]
# Mean 2:  [7.0216487632397939, 4.015507851045852]
# Mean 3:  [5.0119231742792314, 7.0016452217838028]
# Covariance 1:  [[1.028815825073357, 0.027580837408577228], [0.027580837408577228, 3.3870111493054105]]
# Covariance 2:  [[0.99026529171531263, 0.50090264810557183], [0.50090264810557183, 0.99564227689291485]]
# Covariance 3:  [[0.97947613853021465, 0.18500934952834971], [0.18500934952834971, 0.97431245781021458]]
# Weights:  {0: 0.2056901699204417, 1: 0.29842528809574936, 2: 0.49588454198381215}
# =============================================
# Iteration: 50
# Expectation done
# Maximization done
# Mean 1:  [3.040048588126925, 3.049496266379303]
# Mean 2:  [7.0216381410955258, 4.0155021106042215]
# Mean 3:  [5.0118986495610294, 7.0016234407529216]
# Covariance 1:  [[1.0287772619843556, 0.027487638351224242], [0.027487638351224242, 3.3867252661747536]]
# Covariance 2:  [[0.99028328394925669, 0.50090956252989616], [0.50090956252989616, 0.99564305379370921]]
# Covariance 3:  [[0.97950600975856017, 0.18502802356879253], [0.18502802356879253, 0.97434164340045681]]
# Weights:  {0: 0.20567858687575302, 1: 0.29842666490046288, 2: 0.49589474822378432}
# =============================================
# Iteration: 51
# Expectation done
# Maximization done
# Mean 1:  [3.0400047078868608, 3.0493717785677714]
# Mean 2:  [7.0216288080329194, 4.0154970669303651]
# Mean 3:  [5.0118771064199237, 7.0016043056532036]
# Covariance 1:  [[1.0287433898561986, 0.027405788843588619], [0.027405788843588619, 3.3864741819766389]]
# Covariance 2:  [[0.99029909352483014, 0.50091563892904822], [0.50091563892904822, 0.99564373824615893]]
# Covariance 3:  [[0.97953225181537451, 0.18504443259698225], [0.18504443259698225, 0.97436728369822456]]
# Weights:  {0: 0.20566841262022589, 1: 0.29842787463071074, 2: 0.49590371274906248}
# =============================================
# Iteration: 52
# Expectation done
# Maximization done
# Mean 1:  [3.0399661665291178, 3.0492624381840017]
# Mean 2:  [7.0216206081828192, 4.0154926357466634]
# Mean 3:  [5.011858183120216, 7.0015874959474695]
# Covariance 1:  [[1.0287136389551002, 0.027333907587307006], [0.027333907587307006, 3.3862536649682191]]
# Covariance 2:  [[0.99031298416511526, 0.50092097838222738], [0.50092097838222738, 0.9956443410075384]]
# Covariance 3:  [[0.97955530445591654, 0.18505885020632121], [0.18505885020632121, 0.97438980816369425]]
# Weights:  {0: 0.20565947610008503, 1: 0.29842893748546456, 2: 0.49591158641445265}
# =============================================
# Iteration: 53
# Expectation done
# Maximization done
# Mean 1:  [3.0399323153685618, 3.0491664045352045]
# Mean 2:  [7.0216134043923315, 4.0154887429019146]
# Mean 3:  [5.0118415616423002, 7.0015727297265631]
# Covariance 1:  [[1.0286875085386715, 0.027270781206224899], [0.027270781206224899, 3.3860599970638749]]
# Covariance 2:  [[0.99032518797098645, 0.50092566988898912], [0.50092566988898912, 0.99564487164042315]]
# Covariance 3:  [[0.97957555441600297, 0.18507151720234133], [0.18507151720234133, 0.97440959450851139]]
# Weights:  {0: 0.20565162696429701, 1: 0.29842987123898973, 2: 0.49591850179671199}
# =============================================
# Iteration: 54
# Expectation done
# Maximization done
# Mean 1:  [3.0399025843319185, 3.0490820600541997]
# Mean 2:  [7.0216070760070668, 4.015485323169834]
# Mean 3:  [5.0118269624385334, 7.001559759100604]
# Covariance 1:  [[1.0286645585485956, 0.02721534387586548], [0.02721534387586548, 3.385889911703079]]
# Covariance 2:  [[0.99033590915689629, 0.5009297917869967], [0.5009297917869967, 0.99564533863170368]]
# Covariance 3:  [[0.9795933417432845, 0.18508264547241707], [0.18508264547241707, 0.97442697486866969]]
# Weights:  {0: 0.20564473307412531, 1: 0.29843069152792967, 2: 0.49592457539794688}
# =============================================
# Iteration: 55
# Expectation done
# Maximization done
# Mean 1:  [3.0398764724781482, 3.0490079833788934]
# Mean 2:  [7.0216015169096657, 4.015482319186634]
# Mean 3:  [5.0118141398097329, 7.0015483661301561]
# Covariance 1:  [[1.0286444022926435, 0.027166659413957302], [0.027166659413957302, 3.3857405391842534]]
# Covariance 2:  [[0.99034532735852598, 0.50093341300948147], [0.50093341300948147, 0.99564574950321127]]
# Covariance 3:  [[0.9796089653865937, 0.1850924214125709], [0.1850924214125709, 0.97444224125544443]]
# Weights:  {0: 0.20563867830875729, 1: 0.29843141210531915, 2: 0.49592990958592126}
# =============================================
# Iteration: 56
# Expectation done
# Maximization done
# Mean 1:  [3.0398535396508648, 3.0489429256510956]
# Mean 2:  [7.0215966337865821, 4.0154796805131161]
# Mean 3:  [5.0118028778295338, 7.0015383592344484]
# Covariance 1:  [[1.0286267000008138, 0.027123905537191066], [0.027123905537191066, 3.3856093585786726]]
# Covariance 2:  [[0.99035360055796651, 0.50093659419893022], [0.50093659419893022, 0.99564611091356137]]
# Covariance 3:  [[0.97962268812671927, 0.18510100895868198], [0.18510100895868198, 0.97445565036519322]]
# Weights:  {0: 0.20563336063268078, 1: 0.29843204506510518, 2: 0.49593459430221049}
# =============================================
# Iteration: 57
# Expectation done
# Maximization done
# Mean 1:  [3.0398333991306767, 3.0488857896556234]
# Mean 2:  [7.0215923445964146, 4.0154773628050622]
# Mean 3:  [5.0117929867549593, 7.001529570025447]
# Covariance 1:  [[1.0286111531532596, 0.027086360023584492], [0.027086360023584492, 3.3854941554414015]]
# Covariance 2:  [[0.99036086766823139, 0.50093938869236743], [0.50093938869236743, 0.99564642875110188]]
# Covariance 3:  [[0.97963474092423097, 0.18510855226561279], [0.18510855226561279, 0.97446742782157325]]
# Weights:  {0: 0.2056286903941148, 1: 0.29843260104049196, 2: 0.49593870856539424}
# =============================================
# Iteration: 58
# Expectation done
# Maximization done
# Mean 1:  [3.0398157111691537, 3.0488356114652082]
# Mean 2:  [7.0215885772197124, 4.0154753270830374]
# Mean 3:  [5.0117842998650417, 7.0015218505162125]
# Covariance 1:  [[1.0285974994887443, 0.027053388551679897], [0.027053388551679897, 3.3853929846268227]]
# Covariance 2:  [[0.99036725081548516, 0.50094184339241676], [0.50094184339241676, 0.99564670821845869]]
# Covariance 3:  [[0.97964532675087768, 0.18511517807287925], [0.18511517807287925, 0.9744777719144192]]
# Weights:  {0: 0.2056245888274312, 1: 0.29843308937893842, 2: 0.49594232179362696}
# =============================================
# Iteration: 59
# Expectation done
# Maximization done
# Mean 1:  [3.0398001773002625, 3.048791544293505]
# Mean 2:  [7.0215852682662767, 4.0154735390868126]
# Mean 3:  [5.0117766706784552, 7.0015150706621592]
# Covariance 1:  [[1.0285855086135112, 0.027024434013985011], [0.027024434013985011, 3.3853041375981561]]
# Covariance 2:  [[0.99037285735220282, 0.50094399953637536], [0.50094399953637536, 0.99564695390871005]]
# Covariance 3:  [[0.97965462396473113, 0.18512099779236582], [0.18512099779236582, 0.9744868568940559]]
# Weights:  {0: 0.2056209867354401, 1: 0.29843351829658404, 2: 0.49594549496797519}
# =============================================
# Iteration: 60
# Expectation done
# Maximization done
# Mean 1:  [3.0397865353370381, 3.0487528442943108]
# Mean 2:  [7.0215823620256339, 4.0154719687079332]
# Mean 3:  [5.0117699705044894, 7.001509116195245]
# Covariance 1:  [[1.0285749781387776, 0.026999007127038316], [0.026999007127038316, 3.3852261136917616]]
# Covariance 2:  [[0.99037778163295098, 0.50094589337525197], [0.50094589337525197, 0.99564716987419621]]
# Covariance 3:  [[0.97966278928208583, 0.18512610934943891], [0.18512610934943891, 0.97449483587239971]]
# Weights:  {0: 0.20561782333021314, 1: 0.29843389501430423, 2: 0.49594828165548449}
# =============================================
# Iteration: 61
# Expectation done
# Maximization done
# Mean 1:  [3.0397745549716335, 3.0487188580741913]
# Mean 2:  [7.0215798095410937, 4.0154705894886469]
# Mean 3:  [5.0117640862887916, 7.0015038867177823]
# Covariance 1:  [[1.0285657302843405, 0.026976678181235753], [0.026976678181235753, 3.3851575948610368]]
# Covariance 2:  [[0.99038210657888781, 0.50094755677241254], [0.50094755677241254, 0.99564735968796703]]
# Covariance 3:  [[0.97966996039351484, 0.18513059880585814], [0.18513059880585814, 0.97450184337705226]]
# Weights:  {0: 0.20561504521360877, 1: 0.29843422587765045, 2: 0.49595072890873926}
# =============================================
# Iteration: 62
# Expectation done
# Maximization done
# Mean 1:  [3.0397640339067786, 3.0486890117138188]
# Mean 2:  [7.0215775677949939, 4.0154693781815096]
# Mean 3:  [5.0117589187183942, 7.0014992940244261]
# Covariance 1:  [[1.0285576088921873, 0.026957069792689276], [0.026957069792689276, 3.3850974234805702]]
# Covariance 2:  [[0.99038590505640223, 0.50094901773147882], [0.50094901773147882, 0.99564752649893706]]
# Covariance 3:  [[0.97967625826593652, 0.18513454178955596], [0.18513454178955596, 0.97450799759906837]]
# Weights:  {0: 0.20561260548083565, 1: 0.29843451646245522, 2: 0.49595287805670979}
# =============================================
# Iteration: 63
# Expectation done
# Maximization done
# Mean 1:  [3.0397547944548156, 3.0486628011170862]
# Mean 2:  [7.0215755989908617, 4.0154683143611614]
# Mean 3:  [5.0117543805552964, 7.0014952606261964]
# Covariance 1:  [[1.028550476801265, 0.026939850535619987], [0.026939850535619987, 3.3850445828420073]]
# Covariance 2:  [[0.99038924109085724, 0.50095030086136916], [0.50095030086136916, 0.99564767308097668]]
# Covariance 3:  [[0.97968178916797899, 0.1851380047538673], [0.1851380047538673, 0.97451340237080852]]
# Weights:  {0: 0.20561046293231167, 1: 0.29843477166781768, 2: 0.49595476539986832}
# =============================================
# Iteration: 64
# Expectation done
# Maximization done
# Mean 1:  [3.0397466805486308, 3.048639783528754]
# Mean 2:  [7.0215738699221681, 4.0154673800829226]
# Mean 3:  [5.0117503951711404, 7.0014917184518843]
# Covariance 1:  [[1.0285442135399305, 0.026924729348728083], [0.026924729348728083, 3.3849981800164781]]
# Covariance 2:  [[0.99039217093527021, 0.50095142778592727], [0.50095142778592727, 0.99564780187660906]]
# Covariance 3:  [[0.97968664645128467, 0.1851410460860605], [0.1851410460860605, 0.97451814890550392]]
# Weights:  {0: 0.20560858138084187, 1: 0.29843499579794935, 2: 0.495956422821206}
# =============================================
# Iteration: 65
# Expectation done
# Maximization done
# Mean 1:  [3.0397395551142017, 3.0486195700795471]
# Mean 2:  [7.0215723514164781, 4.0154665595824124]
# Mean 3:  [5.0117468952593391, 7.0014886077061469]
# Covariance 1:  [[1.0285387132979045, 0.026911450621682147], [0.026911450621682147, 3.384957430797241]]
# Covariance 2:  [[0.99039474401052852, 0.50095241750450903], [0.50095241750450903, 0.99564791503588179]]
# Covariance 3:  [[0.97969091211711246, 0.18514371708299487], [0.18514371708299487, 0.97452231732738026]]
# Weights:  {0: 0.20560692904269209, 1: 0.29843519263417956, 2: 0.49595787832312815}
# =============================================
# Iteration: 66
# Expectation done
# Maximization done
# Mean 1:  [3.0397332977619875, 3.0486018192351771]
# Mean 2:  [7.021571017846977, 4.0154658390116094]
# Mean 3:  [5.0117438217027228, 7.0014858758654137]
# Covariance 1:  [[1.0285338831440254, 0.026899789879073516], [0.026899789879073516, 3.3849216464716885]]
# Covariance 2:  [[0.99039700373284123, 0.50095328670942374], [0.50095328670942374, 0.99564801445084217]]
# Covariance 3:  [[0.97969465819367818, 0.18514606280949522], [0.18514606280949522, 0.97452597801693441]]
# Weights:  {0: 0.20560547800241835, 1: 0.29843536549829447, 2: 0.49595915649928429}
# =============================================
# Iteration: 67
# Expectation done
# Maximization done
# Mean 1:  [3.0397278027582568, 3.0485862310402085]
# Mean 2:  [7.0215698467019987, 4.0154652062057758]
# Mean 3:  [5.0117411225783206, 7.0014834767950349]
# Covariance 1:  [[1.0285296414602954, 0.026889549989458167], [0.026889549989458167, 3.3848902222000055]]
# Covariance 2:  [[0.99039898824127748, 0.50095405006511251], [0.50095405006511251, 0.99564810178599106]]
# Covariance 3:  [[0.97969794794690168, 0.18514812285345691], [0.18514812285345691, 0.97452919279367778]]
# Weights:  {0: 0.20560420374259211, 1: 0.29843551730826773, 2: 0.49596027894913997}
# =============================================
# Iteration: 68
# Expectation done
# Maximization done
# Mean 1:  [3.0397229772422665, 3.0485725420602732]
# Mean 2:  [7.0215688182078155, 4.0154646504799327]
# Mean 3:  [5.0117387522831791, 7.001481369973745]
# Covariance 1:  [[1.0285259165657523, 0.026880557835674175], [0.026880557835674175, 3.3848626268067785]]
# Covariance 2:  [[0.99040073103788062, 0.50095472045394274], [0.50095472045394274, 0.99564817850540821]]
# Covariance 3:  [[0.97970083694490018, 0.18514993198993721], [0.18514993198993721, 0.97453201595586547]]
# Weights:  {0: 0.20560308473057939, 1: 0.29843565062722854, 2: 0.49596126464219342}
# =============================================
# Iteration: 69
# Expectation done
# Maximization done
# Mean 1:  [3.0397187396604672, 3.0485605209390738]
# Mean 2:  [7.0215679149957229, 4.0154641624487555]
# Mean 3:  [5.0117366707657407, 7.0014795198111832]
# Covariance 1:  [[1.0285226455076781, 0.026872661390275707], [0.026872661390275707, 3.3848383938136535]]
# Covariance 2:  [[0.99040226155021316, 0.5009553091921447], [0.5009553091921447, 0.99564824589655632]]
# Covariance 3:  [[0.97970337399320129, 0.18515152076500843], [0.18515152076500843, 0.97453449519422586]]
# Weights:  {0: 0.20560210205547033, 1: 0.29843576770654601, 2: 0.49596213023798391}
# =============================================
# Iteration: 70
# Expectation done
# Maximization done
# Mean 1:  [3.0397150183905248, 3.0485499644947631]
# Mean 2:  [7.0215671218103095, 4.015463733868974]
# Mean 3:  [5.011734842850629, 7.0014778950487857]
# Covariance 1:  [[1.0285197729994393, 0.026865727147000522], [0.026865727147000522, 3.3848171135626317]]
# Covariance 2:  [[0.99040360562608265, 0.50095582621987933], [0.50095582621987933, 0.9956483050914422]]
# Covariance 3:  [[0.97970560195685241, 0.18515291600913386], [0.18515291600913386, 0.97453667239504582]]
# Weights:  {0: 0.20560123910911635, 1: 0.29843587052367604, 2: 0.49596289036720592}
# =============================================
# Iteration: 71
# Expectation done
# Maximization done
# Mean 1:  [3.03971175053278, 3.0485406942908093]
# Mean 2:  [7.021566425252475, 4.01546335750034]
# Mean 3:  [5.0117332376454256, 7.001476468232922]
# Covariance 1:  [[1.0285172504876312, 0.026859637864886921], [0.026859637864886921, 3.3847984262977535]]
# Covariance 2:  [[0.99040478596829618, 0.50095628026822214], [0.50095628026822214, 0.99564835708519539]]
# Covariance 3:  [[0.97970755848271629, 0.18515414128842139], [0.18515414128842139, 0.97453858434587626]]
# Weights:  {0: 0.2056004813058967, 1: 0.29843596081545271, 2: 0.4959635578786486}
# =============================================
# Iteration: 72
# Expectation done
# Maximization done
# Mean 1:  [3.0397088808482624, 3.0485325536237049]
# Mean 2:  [7.0215658135540817, 4.015463026983987]
# Mean 3:  [5.0117318280197329, 7.0014752152525483]
# Covariance 1:  [[1.0285150353323613, 0.026854290587046657], [0.026854290587046657, 3.3847820160879953]]
# Covariance 2:  [[0.99040582251683895, 0.50095667900601526], [0.50095667900601526, 0.9956484027525272]]
# Covariance 3:  [[0.9797092766341855, 0.18515521730123929], [0.18515521730123929, 0.97454026335565269]]
# Weights:  {0: 0.20559981583657036, 1: 0.29843604010731689, 2: 0.49596414405611422}
# =============================================
# Iteration: 73
# Expectation done
# Maximization done
# Mean 1:  [3.0397063608264108, 3.0485254048773966]
# Mean 2:  [7.021565276379417, 4.015462736735067]
# Mean 3:  [5.0117305901472529, 7.001474114932364]
# Covariance 1:  [[1.0285130900874335, 0.026849594900622414], [0.026849594900622414, 3.3847676054904046]]
# Covariance 2:  [[0.99040673278466307, 0.50095702916890728], [0.50095702916890728, 0.99564844286220155]]
# Covariance 3:  [[0.9797107854487479, 0.18515616222673073], [0.18515616222673073, 0.97454173779942221]]
# Weights:  {0: 0.20559923145202894, 1: 0.29843610973902679, 2: 0.49596465880894264}
# =============================================
# Iteration: 74
# Expectation done
# Maximization done
# Mean 1:  [3.0397041478656175, 3.0485191271990169]
# Mean 2:  [7.0215648046509926, 4.0154624818486786]
# Mean 3:  [5.0117295031034255, 7.0014731486754433]
# Covariance 1:  [[1.0285113818679616, 0.026845471408777671], [0.026845471408777671, 3.3847549508623893]]
# Covariance 2:  [[0.99040753215281496, 0.50095733667275155], [0.50095733667275155, 0.99564847808976387]]
# Covariance 3:  [[0.97971211042779416, 0.18515699203109651], [0.18515699203109651, 0.97454303259693909]]
# Weights:  {0: 0.20559871827337947, 1: 0.29843617088723401, 2: 0.49596511083938877}
# =============================================
# Iteration: 75
# Expectation done
# Maximization done
# Mean 1:  [3.0397022045539175, 3.0485136144577556]
# Mean 2:  [7.0215643903967964, 4.0154622580172381]
# Mean 3:  [5.0117285485124876, 7.0014723001498052]
# Covariance 1:  [[1.0285098817949729, 0.026841850388575388], [0.026841850388575388, 3.3847438382449058]]
# Covariance 2:  [[0.9904082341297491, 0.50095760671331069], [0.50095760671331069, 0.99564850902888657]]
# Covariance 3:  [[0.97971327396707386, 0.18515772073677259], [0.18515772073677259, 0.97454416963327051]]
# Weights:  {0: 0.20559826762508129, 1: 0.29843622458532554, 2: 0.49596550778959236}
# =============================================
# Iteration: 76
# Expectation done
# Maximization done
# Mean 1:  [3.0397004980368107, 3.0485087734519318]
# Mean 2:  [7.0215640266152164, 4.0154620614575451]
# Mean 3:  [5.0117277102368787, 7.001471555012551]
# Covariance 1:  [[1.0285085645075662, 0.026838670612503248], [0.026838670612503248, 3.3847340797467234]]
# Covariance 2:  [[0.99040885057904515, 0.50095784385376474], [0.50095784385376474, 0.99564853620113236]]
# Covariance 3:  [[0.97971429573463387, 0.18515836065881758], [0.18515836065881758, 0.97454516812802927]]
# Weights:  {0: 0.20559787188844325, 1: 0.29843627174085569, 2: 0.49596585637069956}
# =============================================

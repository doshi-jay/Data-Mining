# %%
from scipy.stats import multivariate_normal
from random import randint
import numpy as np

# %%
x, y = [], []
file = open("2gaussian.txt", 'r')
k = 2
for line in file:
    x.append(float(line.split()[0]))
    y.append(float(line.split()[1]))

# %%
u = [[2,2], [6,3]]
cov_mat = [[[1,0],[0,2]], [[1,0.9], [0.9,1]]]
weights = {0: 0.48733333333333334, 1: 0.5126666666666667}
pi_0 = {}
pi_1 = {}

# %%
def probablity(data_point, u, cov_mat):
    var = multivariate_normal(mean=u, cov=cov_mat)
    probability = var.pdf([data_point[0], data_point[1]])
    return probability

# %%
def expectation():
    for i in range(0, len(x)):
        data_point = (x[i], y[i])
        probabilities = []
        for j in range(0, k):
            prob = probablity(data_point, u[j], cov_mat[j])
            if j == 0:
                pi_0[data_point] = prob * weights[0]
            else:
                pi_1[data_point] = prob * weights[1]
            probabilities.append((prob, j))
        denom = 0
        for prob in probabilities:
            label = prob[1]
            denom += prob[0] * weights[label]

        pi_0[data_point] /= denom
        pi_1[data_point] /= denom

# %%
def maximization():
    weights[0] = sum(list(pi_0.values())) / len(x)
    weights[1] = sum(list(pi_1.values())) / len(x)
    sum_u0_x = 0
    sum_u0_y = 0
    sum_u1_x = 0
    sum_u1_y = 0
    for i in range(0, len(x)):
        data_point = (x[i], y[i])
        p0 = pi_0[data_point]
        p1 = pi_1[data_point]
        sum_u0_x += (p0 * x[i])
        sum_u0_y += (p0 * y[i])
        sum_u1_x += (p1 * x[i])
        sum_u1_y += (p1 * y[i])
    sum_u0_x /= sum(list(pi_0.values()))
    sum_u0_y /= sum(list(pi_0.values()))
    sum_u1_x /= sum(list(pi_1.values()))
    sum_u1_y /= sum(list(pi_1.values()))
    u[0][0] = sum_u0_x
    u[0][1] = sum_u0_y
    u[1][0] = sum_u1_x
    u[1][1] = sum_u1_y
    update_cov_mat()

# %%
def update_cov_mat():
    final_cov_mat0 = [[0,0], [0,0]]
    final_cov_mat1 = [[0,0], [0,0]]
    for i in range(len(x)):
        data_point = (x[i], y[i])
        prob0 = pi_0[data_point]
        prob1 = pi_1[data_point]
        
        factor01 = [data_point[0] - u[0][0], data_point[1] - u[0][1]]
        factor01 = np.array(factor01).reshape(1,-1)
        factor02 = np.dot(factor01.reshape(-1,1), factor01)
        factor03 = prob0 * factor02
        
        for m in range(k):
            for n in range(k):
                final_cov_mat0[m][n] += factor03[m][n]
        
        factor11 = [data_point[0] - u[1][0], data_point[1] - u[1][1]]
        factor11 = np.array(factor11).reshape(1,-1)
        factor12 = np.dot(factor11.reshape(-1,1), factor11)
        factor13 = prob1 * factor12
        
        for m in range(k):
            for n in range(k):
                final_cov_mat1[m][n] += factor13[m][n]
                
    for m in range(k):
        for n in range(k):
            final_cov_mat0[m][n] = final_cov_mat0[m][n] / sum(list(pi_0.values()))
    
    for m in range(k):
        for n in range(k):
            final_cov_mat1[m][n] = final_cov_mat1[m][n] / sum(list(pi_1.values()))
    
    cov_mat[0] = final_cov_mat0
    cov_mat[1] = final_cov_mat1

# %%
def repeat_untill_convergence():
    i = 0
    while(i <= 26):
        print("Iteration: " + str(i))
        expectation()
        print("Expectation done")
        maximization()
        print("Maximization done")
        print("Mean 1: ", end = " ")
        print(u[0])
        print("Mean 2: ", end = " ")
        print(u[1])
        print("Covariance 1: ", end = " ")
        print(cov_mat[0])
        print("Covariance 2: ", end = " ")
        print(cov_mat[1])
        print("Weights: ", end = " ")
        print(weights)
        print("=============================================")
        i += 1

# %%
repeat_untill_convergence()
# Out:
# Iteration: 0
# Expectation done
# Maximization done
# [2.868938552786409, 3.069212492675539]
# [6.928626743983444, 3.942774137525465]
# [[0.8398859825126438, 0.04710994849518981], [0.04710994849518981, 3.054032553967042]]
# [[1.1515339886138152, 0.5792466055083737], [0.5792466055083737, 1.0596885803419758]]
# {0: 0.3106219195930774, 1: 0.6893780804069234}
# =============================================
# Iteration: 1
# Expectation done
# Maximization done
# [2.90906421007665, 3.0660489065491436]
# [6.960640448171374, 3.9551929606253466]
# [[0.8861286162292746, 0.04627210520152532], [0.04627210520152532, 3.0105651477072133]]
# [[1.0783713442719545, 0.5519768809926096], [0.5519768809926096, 1.042793925891946]]
# {0: 0.3191453812294417, 1: 0.6808546187705568}
# =============================================
# Iteration: 2
# Expectation done
# Maximization done
# [2.93658658007129, 3.0613610070872737]
# [6.979715109576201, 3.9645332220784373]
# [[0.9224203985857908, 0.040739045574489936], [0.040739045574489936, 2.9849408033861278]]
# [[1.0380317705062352, 0.5324648732236875], [0.5324648732236875, 1.0290134889689415]]
# {0: 0.3245300006953714, 1: 0.6754699993046256}
# =============================================
# Iteration: 3
# Expectation done
# Maximization done
# [2.955287990842243, 3.057970434429851]
# [6.991444927412354, 3.970847418421488]
# [[0.9492606512777496, 0.03602639054892366], [0.03602639054892366, 2.968942560508051]]
# [[1.014699740084412, 0.5199736603851706], [0.5199736603851706, 1.019488827737704]]
# {0: 0.3279967412399179, 1: 0.6720032587600834}
# =============================================
# Iteration: 4
# Expectation done
# Maximization done
# [2.967929829950484, 3.055816394926031]
# [6.998870781573238, 3.9749991417921597]
# [[0.9683650981802612, 0.0328445867881578], [0.0328445867881578, 2.9585694140811296]]
# [[1.0005558712871223, 0.5120970060703675], [0.5120970060703675, 1.0132271997658355]]
# {0: 0.33026337831936103, 1: 0.6697366216806433}
# =============================================
# Iteration: 5
# Expectation done
# Maximization done
# [2.9764580266159655, 3.0544798995031845]
# [7.003672812801761, 3.9777231772286097]
# [[0.9816684156120198, 0.030823141745709735], [0.030823141745709735, 2.9517209973443146]]
# [[0.9916744696173452, 0.5070788975608594], [0.5070788975608594, 1.0091443281454824]]
# {0: 0.3317613483890437, 1: 0.6682386516109563}
# =============================================
# Iteration: 6
# Expectation done
# Maximization done
# [2.9822081973629557, 3.0536439632914143]
# [7.006823183075039, 3.9795197033872363]
# [[0.9908187927668726, 0.02954876880812325], [0.02954876880812325, 2.9471592766096326]]
# [[0.9859610852010531, 0.503835407392918], [0.503835407392918, 1.0064693293503644]]
# {0: 0.3327584334762367, 1: 0.6672415665237634}
# =============================================
# Iteration: 7
# Expectation done
# Maximization done
# [2.9860856763093624, 3.053112575103062]
# [7.008909899776123, 3.9807117612576226]
# [[0.9970684804551322, 0.028737530790524157], [0.028737530790524157, 2.9441058235680426]]
# [[0.9822258911545196, 0.5017124184270051], [0.5017124184270051, 1.0047038439942961]]
# {0: 0.3334252803956089, 1: 0.6665747196043897}
# =============================================
# Iteration: 8
# Expectation done
# Maximization done
# [2.9887011093139386, 3.052769383639341]
# [7.010300925869185, 3.981506793305147]
# [[1.0013192681415284, 0.02821408199874682], [0.02821408199874682, 2.94205586007976]]
# [[0.9797576407930474, 0.5003095039492631], [0.5003095039492631, 1.003531000440258]]
# {0: 0.33387268301966766, 1: 0.6661273169803335}
# =============================================
# Iteration: 9
# Expectation done
# Maximization done
# [2.990465793403153, 3.052544860688431]
# [7.011232153223717, 3.9820390719245284]
# [[1.0042031454406581, 0.027872139550424935], [0.027872139550424935, 2.9406769478368884]]
# [[0.9781149076862355, 0.49937606704127124], [0.49937606704127124, 1.0027479529253958]]
# {0: 0.33417349527348167, 1: 0.6658265047265208}
# =============================================
# Iteration: 10
# Expectation done
# Maximization done
# [2.991656756288728, 3.0523965493432166]
# [7.011857346881553, 3.9823964106336374]
# [[1.0061565480640013, 0.027646579958236075], [0.027646579958236075, 2.9397482301718174]]
# [[0.9770163607396481, 0.49875203772820953], [0.49875203772820953, 1.0022232700229674]]
# {0: 0.33437603709193325, 1: 0.6656239629080678}
# =============================================
# Iteration: 11
# Expectation done
# Maximization done
# [2.992460674517256, 3.052297901555354]
# [7.012277884909113, 3.9826367606919177]
# [[1.0074783401114085, 0.027496718277113922], [0.027496718277113922, 2.9391221843332094]]
# [[0.9762793716910677, 0.4983334936961955], [0.4983334936961955, 1.001870823577022]]
# {0: 0.3345125435923919, 1: 0.6654874564076099}
# =============================================
# Iteration: 12
# Expectation done
# Maximization done
# [2.9930034066968485, 3.052231969678915]
# [7.012561125714546, 3.982798632718782]
# [[1.008372151303543, 0.02739664011043964], [0.02739664011043964, 2.9386999215608203]]
# [[0.975783877841689, 0.4980521478926015], [0.4980521478926015, 1.0016336669549906]]
# {0: 0.3346046044485613, 1: 0.6653953955514393}
# =============================================
# Iteration: 13
# Expectation done
# Maximization done
# [2.9933698458400873, 3.0521877570349045]
# [7.01275205985333, 3.9829077471911845]
# [[1.0089762924591184, 0.027329569307684383], [0.027329569307684383, 2.938414995730335]]
# [[0.975450263433432, 0.49786274256947594], [0.49786274256947594, 1.0014739007469464]]
# {0: 0.3346667182033813, 1: 0.6653332817966182}
# =============================================
# Iteration: 14
# Expectation done
# Maximization done
# [2.9936172732741793, 3.0521580415193665]
# [7.012880844983269, 3.982981342871133]
# [[1.009384522532707, 0.027284509365317986], [0.027284509365317986, 2.9382226875869795]]
# [[0.9752254224920178, 0.4977351030830922], [0.4977351030830922, 1.0013661851578677]]
# {0: 0.3347086390073975, 1: 0.6652913609925988}
# =============================================
# Iteration: 15
# Expectation done
# Maximization done
# [2.993784349378631, 3.052138038744588]
# [7.012967744921387, 3.9830310018391537]
# [[1.0096603182227188, 0.02725418626546465], [0.02725418626546465, 2.938092867273723]]
# [[0.9750737901107133, 0.49764902830822716], [0.49764902830822716, 1.0012935235809186]]
# {0: 0.334736937191993, 1: 0.6652630628080064}
# =============================================
# Iteration: 16
# Expectation done
# Maximization done
# [2.993897171659125, 3.0521245599324693]
# [7.013026397759663, 3.9830645185627147]
# [[1.0098466185596073, 0.027233757127029738], [0.027233757127029738, 2.9380052194403965]]
# [[0.9749714840310107, 0.4975909561523774], [0.4975909561523774, 1.001244490605236]]
# {0: 0.33475604216402216, 1: 0.6652439578359738}
# =============================================
# Iteration: 17
# Expectation done
# Maximization done
# [2.9939733593804068, 3.0521154708386318]
# [7.013065992434395, 3.9830871444411606]
# [[1.009972453716073, 0.02721998309286871], [0.02721998309286871, 2.93794603930663]]
# [[0.9749024376163894, 0.4975517642949973], [0.4975517642949973, 1.0012113944283212]]
# {0: 0.33476894169705457, 1: 0.665231058302944}
# =============================================
# Iteration: 18
# Expectation done
# Maximization done
# [2.9940248089333164, 3.0521093389032408]
# [7.013092724794879, 3.983102420220547]
# [[1.0100574431450944, 0.027210691314622008], [0.027210691314622008, 2.9379060784128512]]
# [[0.9748558287320052, 0.49752530882653845], [0.49752530882653845, 1.0011890515518949]]
# {0: 0.33477765190289693, 1: 0.6652223480971036}
# =============================================
# Iteration: 19
# Expectation done
# Maximization done
# [2.994059553159402, 3.052105200668231]
# [7.013110774639844, 3.983112734473818]
# [[1.0101148429873377, 0.027204420993616394], [0.027204420993616394, 2.937879094122688]]
# [[0.9748243617118678, 0.497507448187755], [0.497507448187755, 1.0011739664331576]]
# {0: 0.3347835335772969, 1: 0.6652164664227028}
# =============================================
# Iteration: 20
# Expectation done
# Maximization done
# [2.994083016328551, 3.05210240730297]
# [7.01312296267523, 3.983119699084419]
# [[1.0101536084470097, 0.02720018861690605], [0.02720018861690605, 2.9378608720409964]]
# [[0.9748031154470939, 0.49749538893696166], [0.49749538893696166, 1.001163780728953]]
# {0: 0.334787505362782, 1: 0.6652124946372201}
# =============================================
# Iteration: 21
# Expectation done
# Maximization done
# [2.994098861346111, 3.0521005214645585]
# [7.013131192871419, 3.9831244020578263]
# [[1.0101797885522863, 0.027197331362791854], [0.027197331362791854, 2.9378485667316276]]
# [[0.9747887692560276, 0.49748724617204315], [0.49748724617204315, 1.0011569028353837]]
# {0: 0.33479018748682216, 1: 0.6652098125131799}
# =============================================
# Iteration: 22
# Expectation done
# Maximization done
# [2.9941095617494415, 3.0520992481826235]
# [7.013136750603961, 3.9831275779038564]
# [[1.0101974689725313, 0.027195402236251016], [0.027195402236251016, 2.937840256900652]]
# [[0.9747790818188721, 0.4974817476935718], [0.4974817476935718, 1.0011522583805696]]
# {0: 0.33479199873314985, 1: 0.6652080012668503}
# =============================================
# Iteration: 23
# Expectation done
# Maximization done
# [2.9941167879247943, 3.052098388429136]
# [7.013140503724454, 3.9831297225415994]
# [[1.010209409134885, 0.02719409965592203], [0.02719409965592203, 2.937834645189724]]
# [[0.9747725400752414, 0.49747803468430446], [0.49747803468430446, 1.0011491220336641]]
# {0: 0.33479322188379423, 1: 0.6652067781162012}
# =============================================
# Iteration: 24
# Expectation done
# Maximization done
# [2.9941216678983493, 3.0520978078745022]
# [7.0131430382248485, 3.983131170825001]
# [[1.0102174726700714, 0.02719322008695818], [0.02719322008695818, 2.9378308555255694]]
# [[0.9747681224743924, 0.4974755273154223], [0.4974755273154223, 1.001147004061542]]
# {0: 0.33479404789307593, 1: 0.6652059521069243}
# =============================================
# Iteration: 25
# Expectation done
# Maximization done
# [2.9941249634404477, 3.0520974158388157]
# [7.013144749798633, 3.9831321488650686]
# [[1.010222918187109, 0.02719262613700798], [0.02719262613700798, 2.937828296304967]]
# [[0.9747651392560157, 0.497473834084094], [0.497473834084094, 1.0011455737818593]]
# {0: 0.3347946057099183, 1: 0.6652053942900786}
# =============================================
# Iteration: 26
# Expectation done
# Maximization done
# [2.9941271889863152, 3.0520971511003006]
# [7.0131459056477485, 3.9831328093487066]
# [[1.0102265956785188, 0.02719222504902605], [0.02719222504902605, 2.9378265680182394]]
# [[0.9747631246625434, 0.4974726906310682], [0.4974726906310682, 1.0011446078982342]]
# {0: 0.33479498241326877, 1: 0.6652050175867288}
# =============================================
